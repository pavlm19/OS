# %%
import torch 
import pandas as pd 
import torch.nn as nn 
from torch.utils.data import random_split, DataLoader, TensorDataset 
import torch.nn.functional as F 
import numpy as np 
import torch.optim as optim 
from torch.optim import Adam

# %%
# Loading the Data
df = pd.read_csv('dataset.csv') 
df.head()
# Out:
#    Initial packet size  Initial TTL  ...  sackOK   Target
# 0                   66          128  ...       1  windows
# 1                   66          128  ...       1  windows
# 2                   66           54  ...       1  windows
# 3                   54          128  ...       0  windows
# 4                   66           55  ...       1  windows
#
# [5 rows x 9 columns]

# %%
del df['port']
df
# Out:
#       Initial packet size  Initial TTL  ...  sackOK   Target
# 0                      66          128  ...       1  windows
# 1                      66          128  ...       1  windows
# 2                      66           54  ...       1  windows
# 3                      54          128  ...       0  windows
# 4                      66           55  ...       1  windows
# ...                   ...          ...  ...     ...      ...
# 5679                  180           64  ...       0  android
# 5680                  590           64  ...       0  android
# 5681                  384           64  ...       0  android
# 5682                  312           16  ...       0  android
# 5683                  371           16  ...       0  android
#
# [5684 rows x 8 columns]

# %%
df.iloc[:,-1].value_counts()
# Out:
# windows    3978
# android     883
# linux       823
# Name: Target, dtype: int64

# %%
# Convert Iris species into numeric types: windows=0, android=1, linux=2.  
labels = {'windows':0, 'android':1, 'linux':2} 
df['Target_num'] = df['Target']   # Create a new column "Target_num" 
df.Target_num = [labels[item] for item in df.Target_num]  # Convert the values to numeric ones 
df
# Out:
#       Initial packet size  Initial TTL  ...   Target  Target_num
# 0                      66          128  ...  windows           0
# 1                      66          128  ...  windows           0
# 2                      66           54  ...  windows           0
# 3                      54          128  ...  windows           0
# 4                      66           55  ...  windows           0
# ...                   ...          ...  ...      ...         ...
# 5679                  180           64  ...  android           1
# 5680                  590           64  ...  android           1
# 5681                  384           64  ...  android           1
# 5682                  312           16  ...  android           1
# 5683                  371           16  ...  android           1
#
# [5684 rows x 9 columns]

# %%
# Define input and output datasets 
input = df.iloc[:,:-2]            # inputs. 
print('\nInput values are:') 
print(input.head())   
output = df.loc[:, 'Target_num']   # targets
print('\nThe output value is:') 
print(output.head())
# Out:
# Input values are:
#    Initial packet size  Initial TTL  ...  Window Scalling Value  sackOK
# 0                   66          128  ...                      8       1
# 1                   66          128  ...                      8       1
# 2                   66           54  ...                      8       1
# 3                   54          128  ...                      0       0
# 4                   66           55  ...                      8       1
#
# [5 rows x 7 columns]
#
# The output value is:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Target_num, dtype: int64

# %%
# Convert Input and Output data to Tensors and create a TensorDataset 
input = torch.Tensor(input.to_numpy())      # Create tensor of type torch.float32 
print('\nInput format: ', input.shape, input.dtype)     # Input format: torch.Size([5684, 7]) torch.float32 
output = torch.tensor(output.to_numpy())        # Create tensor type torch.int64  
print('Output format: ', output.shape, output.dtype)  # Output format: torch.Size([5684]) torch.int64 
data = TensorDataset(input, output)    # Create a torch.utils.data.TensorDataset object for further data manipulation
# Out:
# Input format:  torch.Size([5684, 7]) torch.float32
# Output format:  torch.Size([5684]) torch.int64

# %%
data

# %%
# Split to Train, Validate and Test sets using random_split 
train_batch_size = 128        
number_rows = len(input)    # The size of our dataset or the number of rows in excel table.  
test_split = int(number_rows*0.3)  
validate_split = int(number_rows*0.2) 
train_split = number_rows - test_split - validate_split     
train_set, validate_set, test_set = random_split( 
    data, [train_split, validate_split, test_split])    
 
# Create Dataloader to read the data within batch sizes and put into memory. 
train_loader = DataLoader(train_set, batch_size = train_batch_size, shuffle = True) 
validate_loader = DataLoader(validate_set, batch_size = 1) 
test_loader = DataLoader(test_set, batch_size = 1)

# %%
# Define model parameters 
input_size = list(input.shape)[1]   # = 7. The input depends on how many features we initially feed the model. In our case, there are 4 features for every predict value  
learning_rate = 0.01 
output_size = len(labels)           # The output is prediction results


# Define neural network 
class Network(nn.Module): 
   def __init__(self, input_size, output_size): 
       super(Network, self).__init__() 
        
       self.layer1 = nn.Linear(input_size, 24) 
       self.layer2 = nn.Linear(24, 24) 
       self.layer3 = nn.Linear(24, output_size) 

   def forward(self, x): 
       x1 = F.relu(self.layer1(x)) 
       x2 = F.relu(self.layer2(x1)) 
       x3 = self.layer3(x2)
       return x3 
 
# Instantiate the model 
model = Network(input_size, output_size)

# %%
# Function to save the model 
def saveModel(): 
    path = "./NetModel.pth" 
    torch.save(model.state_dict(), path)

# %%
# Define the loss function with Classification Cross-Entropy loss and an optimizer with Adam optimizer
loss_fn = nn.CrossEntropyLoss()
optimizer = Adam(model.parameters(), lr=0.001, weight_decay=0.0001)

# %%
# Training Function 
def train(num_epochs): 
    best_accuracy = 0.0 
     
    print("Begin training...") 
    for epoch in range(1, num_epochs+1): 
        running_train_loss = 0.0 
        running_accuracy = 0.0 
        running_vall_loss = 0.0 
        total = 0 
 
        # Training Loop 
        for data in train_loader: 
        #for data in enumerate(train_loader, 0): 
            inputs, outputs = data  # get the input and real species as outputs; data is a list of [inputs, outputs] 
            optimizer.zero_grad()   # zero the parameter gradients          
            predicted_outputs = model(inputs)   # predict output from the model 
            train_loss = loss_fn(predicted_outputs, outputs)   # calculate loss for the predicted output  
            train_loss.backward()   # backpropagate the loss 
            optimizer.step()        # adjust parameters based on the calculated gradients 
            running_train_loss +=train_loss.item()  # track the loss value 
 
        # Calculate training loss value 
        train_loss_value = running_train_loss/len(train_loader) 
 
        # Validation Loop 
        with torch.no_grad(): 
            model.eval() 
            for data in validate_loader: 
               inputs, outputs = data 
               predicted_outputs = model(inputs) 
               val_loss = loss_fn(predicted_outputs, outputs) 
             
               # The label with the highest value will be our prediction 
               _, predicted = torch.max(predicted_outputs, 1) 
               running_vall_loss += val_loss.item()  
               total += outputs.size(0) 
               running_accuracy += (predicted == outputs).sum().item() 
 
        # Calculate validation loss value 
        val_loss_value = running_vall_loss/len(validate_loader) 
                
        # Calculate accuracy as the number of correct predictions in the validation batch divided by the total number of predictions done.  
        accuracy = (100 * running_accuracy / total)     
 
        # Save the model if the accuracy is the best 
        if accuracy > best_accuracy: 
            saveModel() 
            best_accuracy = accuracy 
         
        # Print the statistics of the epoch 
        print('Completed training batch', epoch, 'Training Loss is: %.4f' %train_loss_value, 'Validation Loss is: %.4f' %val_loss_value, 'Accuracy is %d %%' % (accuracy))

# %%
# Function to test the model 
def test(): 
    # Load the model that we saved at the end of the training loop 
    model = Network(input_size, output_size) 
    path = "NetModel.pth" 
    model.load_state_dict(torch.load(path)) 
     
    running_accuracy = 0 
    total = 0 
 
    with torch.no_grad(): 
        for data in test_loader: 
            inputs, outputs = data 
            outputs = outputs.to(torch.float32) 
            predicted_outputs = model(inputs) 
            _, predicted = torch.max(predicted_outputs, 1) 
            total += outputs.size(0) 
            running_accuracy += (predicted == outputs).sum().item() 
 
        print('Accuracy of the model based on the test set of', test_split ,'inputs is: %d %%' % (100 * running_accuracy / total))    
 
 
# Optional: Function to test which species were easier to predict  
def test_species(): 
    # Load the model that we saved at the end of the training loop 
    model = Network(input_size, output_size) 
    path = "NetModel.pth" 
    model.load_state_dict(torch.load(path)) 
     
    labels_length = len(labels) # how many classes we have. = 3 in our database. 
    labels_correct = list(0. for i in range(labels_length)) # list to calculate correct labels  
    labels_total = list(0. for i in range(labels_length))   # list to keep the total num of labels per type 
  
    with torch.no_grad(): 
        for data in test_loader: 
            inputs, outputs = data 
            predicted_outputs = model(inputs) 
            _, predicted = torch.max(predicted_outputs, 1) 
             
            label_correct_running = (predicted == outputs).squeeze() 
            label = outputs[0] 
            if label_correct_running.item():  
                labels_correct[label] += 1 
            labels_total[label] += 1  
  
    label_list = list(labels.keys()) 
    for i in range(output_size): 
        print('Accuracy to predict %5s : %2d %%' % (label_list[i], 100 * labels_correct[i] / labels_total[i]))

# %%
if __name__ == "__main__": 
    num_epochs = 50
    train(num_epochs) 
    print('Finished Training\n') 
    test() 
    test_species()
# Out:
# Begin training...
# Completed training batch 1 Training Loss is: 172.4388 Validation Loss is: 91.2868 Accuracy is 66 %
# Completed training batch 2 Training Loss is: 37.5973 Validation Loss is: 37.8034 Accuracy is 29 %
# Completed training batch 3 Training Loss is: 28.0436 Validation Loss is: 11.2856 Accuracy is 68 %
# Completed training batch 4 Training Loss is: 20.0694 Validation Loss is: 18.3414 Accuracy is 68 %
# Completed training batch 5 Training Loss is: 14.7538 Validation Loss is: 13.5802 Accuracy is 68 %
# Completed training batch 6 Training Loss is: 7.2379 Validation Loss is: 4.3473 Accuracy is 69 %
# Completed training batch 7 Training Loss is: 7.1497 Validation Loss is: 5.3867 Accuracy is 32 %
# Completed training batch 8 Training Loss is: 8.9107 Validation Loss is: 20.7976 Accuracy is 69 %
# Completed training batch 9 Training Loss is: 16.2404 Validation Loss is: 5.6582 Accuracy is 41 %
# Completed training batch 10 Training Loss is: 12.3257 Validation Loss is: 15.5134 Accuracy is 62 %
# Completed training batch 11 Training Loss is: 16.2751 Validation Loss is: 25.1211 Accuracy is 44 %
# Completed training batch 12 Training Loss is: 13.7000 Validation Loss is: 23.0641 Accuracy is 41 %
# Completed training batch 13 Training Loss is: 16.5378 Validation Loss is: 8.7394 Accuracy is 67 %
# Completed training batch 14 Training Loss is: 18.4355 Validation Loss is: 7.0872 Accuracy is 44 %
# Completed training batch 15 Training Loss is: 10.2464 Validation Loss is: 8.3776 Accuracy is 49 %
# Completed training batch 16 Training Loss is: 6.6054 Validation Loss is: 9.1924 Accuracy is 68 %
# Completed training batch 17 Training Loss is: 10.1690 Validation Loss is: 2.2348 Accuracy is 53 %
# Completed training batch 18 Training Loss is: 9.4559 Validation Loss is: 6.4692 Accuracy is 67 %
# Completed training batch 19 Training Loss is: 6.1609 Validation Loss is: 8.0823 Accuracy is 69 %
# Completed training batch 20 Training Loss is: 8.1745 Validation Loss is: 12.7774 Accuracy is 70 %
# Completed training batch 21 Training Loss is: 8.5202 Validation Loss is: 10.0962 Accuracy is 44 %
# Completed training batch 22 Training Loss is: 5.3810 Validation Loss is: 2.5503 Accuracy is 72 %
# Completed training batch 23 Training Loss is: 4.7660 Validation Loss is: 14.6852 Accuracy is 32 %
# Completed training batch 24 Training Loss is: 17.3893 Validation Loss is: 5.7651 Accuracy is 73 %
# Completed training batch 25 Training Loss is: 10.5793 Validation Loss is: 17.6477 Accuracy is 71 %
# Completed training batch 26 Training Loss is: 9.1075 Validation Loss is: 3.8633 Accuracy is 75 %
# Completed training batch 27 Training Loss is: 7.5810 Validation Loss is: 18.8481 Accuracy is 29 %
# Completed training batch 28 Training Loss is: 9.1249 Validation Loss is: 15.1934 Accuracy is 32 %
# Completed training batch 29 Training Loss is: 14.1739 Validation Loss is: 20.5309 Accuracy is 27 %
# Completed training batch 30 Training Loss is: 12.1141 Validation Loss is: 11.4697 Accuracy is 53 %
# Completed training batch 31 Training Loss is: 14.0425 Validation Loss is: 21.8993 Accuracy is 31 %
# Completed training batch 32 Training Loss is: 9.1869 Validation Loss is: 7.3502 Accuracy is 69 %
# Completed training batch 33 Training Loss is: 4.5129 Validation Loss is: 1.3183 Accuracy is 72 %
# Completed training batch 34 Training Loss is: 7.3797 Validation Loss is: 1.6013 Accuracy is 72 %
# Completed training batch 35 Training Loss is: 4.9421 Validation Loss is: 2.4966 Accuracy is 73 %
# Completed training batch 36 Training Loss is: 3.8294 Validation Loss is: 2.1513 Accuracy is 70 %
# Completed training batch 37 Training Loss is: 4.7970 Validation Loss is: 7.0848 Accuracy is 33 %
# Completed training batch 38 Training Loss is: 10.6110 Validation Loss is: 11.4404 Accuracy is 64 %
# Completed training batch 39 Training Loss is: 7.4202 Validation Loss is: 2.2579 Accuracy is 72 %
# Completed training batch 40 Training Loss is: 6.6111 Validation Loss is: 16.2018 Accuracy is 32 %
# Completed training batch 41 Training Loss is: 9.8751 Validation Loss is: 11.6489 Accuracy is 35 %
# Completed training batch 42 Training Loss is: 9.1515 Validation Loss is: 9.6094 Accuracy is 43 %
# Completed training batch 43 Training Loss is: 5.2210 Validation Loss is: 1.9136 Accuracy is 74 %
# Completed training batch 44 Training Loss is: 3.5196 Validation Loss is: 2.9990 Accuracy is 76 %
# Completed training batch 45 Training Loss is: 5.9178 Validation Loss is: 4.6652 Accuracy is 60 %
# Completed training batch 46 Training Loss is: 2.2112 Validation Loss is: 4.8706 Accuracy is 41 %
# Completed training batch 47 Training Loss is: 5.3263 Validation Loss is: 11.9930 Accuracy is 32 %
# Completed training batch 48 Training Loss is: 5.0490 Validation Loss is: 5.8639 Accuracy is 53 %
# Completed training batch 49 Training Loss is: 4.3248 Validation Loss is: 7.0564 Accuracy is 41 %
# Completed training batch 50 Training Loss is: 5.7403 Validation Loss is: 6.5476 Accuracy is 76 %
# Finished Training
#
# Accuracy of the model based on the test set of 1705 inputs is: 75 %
# Accuracy to predict windows : 99 %
# Accuracy to predict android : 42 %
# Accuracy to predict linux :  0 %
